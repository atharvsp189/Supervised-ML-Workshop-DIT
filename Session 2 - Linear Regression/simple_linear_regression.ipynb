# %% [markdown]
# ## Simple Linear Regression
# Simple
# linear regression can be used to model a linear relationship between one response
# variable and one explanatory variable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data
# Data in 100 sqft
X = np.array([[6], [8], [10], [14], [18]])
# Rent in K 1000
y = np.array([[7], [9], [13], [17.5], [18]])

# %%
plt.figure()
plt.xlabel("House Size (100 sqft)")
plt.ylabel("Rent (1K INR)")
plt.title("Linear Regression: House Size vs Rent")
plt.plot(X, y, 'k.')
plt.grid(True)
plt.show()

# %%
class LinearRegression:
    def __init__(self, lr = 0.001, n_iters=100):
        self.lr = lr
        self.n_iters = n_iters
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.n_iters):
            y_pred = np.dot(X, self.weights) + self.bias

            dw = (1/n_samples) * np.dot(X.T, (y_pred-y))
            db = (1/n_samples) * np.sum(y_pred-y)

            self.weights = self.weights - self.lr * dw
            self.bias = self.bias - self.lr * db

    def predict(self, x):
        y_pred = np.dot(x, self.weights) + self.bias
        return y_pred

# %%
model = LinearRegression()

# %%
model.fit(X, y)

# %%
plt.figure()
plt.xlabel("House Size (100 sqft)")
plt.ylabel("Rent (1K INR)")
plt.title("Linear Regression: House Size vs Rent")
plt.plot(X, y, 'k.')
plt.plot(X, model.predict(X),'g')
plt.grid(True)
plt.show()

# %%
print ('Mean Absolute Deviation: %.2f' % np.mean(abs(model.predict(X)- y)))
print ('Residual sum of squares: %.2f' % np.mean((model.predict(X)- y) ** 2))
# Out:
# Mean Absolute Deviation: 1.15
# Residual sum of squares: 2.02
